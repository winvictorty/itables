# %% [markdown]
# # Downsampling
#
# When an interactive table is displayed by `itables`, the table data is embedded in the notebook output. As we don't want your notebook to become super heavy just because you displayed a large table, we have a downsampling mechanism in place.
#
# When the data in a table is larger than `maxBytes`, which is equal to 64KB by default, `itables` will display only a subset of the table - one that fits into `maxBytes`, and display a warning that points to the `itables` documentation.
#
# If you wish, you can increase the value of `maxBytes` or even deactivate the limit (with `maxBytes=0`). Similarly you can set a limit on the number of rows (`maxRows`, defaults to 0) or columns (`maxColumns`, defaults to `pd.get_option('display.max_columns')`).

# %%
from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=True)

# %%
from itables.sample_dfs import get_indicators
import itables.options as opt

opt.lengthMenu = [2, 5, 10, 20, 50, 100, 200, 500]
opt.maxBytes = 10000

df = get_indicators()
df.values.nbytes
# Out:
# 28000

# %%
df
# Out:
# WARNING:itables.downsample:showing 250x3 of 500x7 as nbytes=28000>10000=maxBytes. See https://mwouts.github.io/itables/downsampling.html
#                             id  \
# 0           1.0.HCount.1.90usd
# 1            1.0.HCount.2.5usd
# 2         1.0.HCount.Mid10to50
# 3              1.0.HCount.Ofcl
# 4          1.0.HCount.Poor4uds
# ..                         ...
# 495    5.2.11_ETH.BAS.AID.JICA
# 496      5.2.11_KHM.BAS.AID.WB
# 497   5.2.11_LAO.BAS.AID.INGOS
# 498      5.2.11_MWI.BAS.AID.WB
# 499  5.2.11_TLS.TOT.AID.UNICEF
#
#                                                   name  unit  \
# 0                      Poverty Headcount ($1.90 a day)   NaN
# 1                      Poverty Headcount ($2.50 a day)   NaN
# 2                Middle Class ($10-50 a day) Headcount   NaN
# 3              Official Moderate Poverty Rate-National   NaN
# 4                         Poverty Headcount ($4 a day)   NaN
# ..                                                 ...   ...
# 495  International aid disbursed to basic education...   NaN
# 496   International aid disbursed to basic educatio...   NaN
# 497   International aid disbursed to basic educatio...   NaN
# 498  International aid disbursed to basic education...   NaN
# 499   International aid disbursed to total educatio...   NaN
#
#                                source  \
# 0                      LAC Equity Lab
# 1                      LAC Equity Lab
# 2                      LAC Equity Lab
# 3                      LAC Equity Lab
# 4                      LAC Equity Lab
# ..                                ...
# 495  Global Partnership for Education
# 496  Global Partnership for Education
# 497  Global Partnership for Education
# 498  Global Partnership for Education
# 499  Global Partnership for Education
#
#                                             sourceNote  \
# 0    The poverty headcount index measures the propo...
# 1    The poverty headcount index measures the propo...
# 2    The poverty headcount index measures the propo...
# 3    The poverty headcount index measures the propo...
# 4    The poverty headcount index measures the propo...
# ..                                                 ...
# 495  International concessional aid disbursed by th...
# 496  International concessional aid disbursed by th...
# 497  International concessional aid disbursed by th...
# 498  International concessional aid disbursed by th...
# 499  International concessional aid disbursed by th...
#
#                                     sourceOrganization   topics
# 0    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 1    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 2    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 3    LAC Equity Lab tabulations of data from Nation...  Poverty
# 4    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# ..                                                 ...      ...
# 495  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 496  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 497  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 498  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 499  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
#
# [500 rows x 7 columns]

# %% [markdown]
# To show the table in full, we can modify the value of `maxBytes` either locally:

# %%
show(df, maxBytes=0)
# Out:
# <table id="d5a15d83-4278-458b-8c7b-98888c5f571d" class="display"style="max-width:100%"><thead>
#     <tr style="text-align: right;">
#
#       <th>id</th>
#       <th>name</th>
#       <th>unit</th>
#       <th>source</th>
#       <th>sourceNote</th>
#       <th>sourceOrganization</th>
#       <th>topics</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [["1.0.HCount.1.90usd", "Poverty Headcount ($1.90 a day)", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income (in 2011 PPP) below the poverty line.", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.HCount.2.5usd", "Poverty Headcount ($2.50 a day)", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.HCount.Mid10to50", "Middle Class ($10-50 a day) Headcount", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.HCount.Ofcl", "Official Moderate Poverty Rate-National", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income below the official poverty line developed by each country.", "LAC Equity Lab tabulations of data from National Statistical Offices.", "Poverty"], ["1.0.HCount.Poor4uds", "Poverty Headcount ($4 a day)", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.HCount.Vul4to10", "Vulnerable ($4-10 a day) Headcount", NaN, "LAC Equity Lab", "The poverty headcount index measures the proportion of the population with daily per capita income (in 2005 PPP) below the poverty line.", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PGap.1.90usd", "Poverty Gap ($1.90 a day)", NaN, "LAC Equity Lab", "The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PGap.2.5usd", "Poverty Gap ($2.50 a day)", NaN, "LAC Equity Lab", "The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PGap.Poor4uds", "Poverty Gap ($4 a day)", NaN, "LAC Equity Lab", "The poverty gap captures the mean aggregate income or consumption shortfall relative to the poverty line across the entire population. It measures the total resources needed to bring all the poor to the level of the poverty line (averaged over the total population). ", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PSev.1.90usd", "Poverty Severity ($1.90 a day)", NaN, "LAC Equity Lab", "The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PSev.2.5usd", "Poverty Severity ($2.50 a day)", NaN, "LAC Equity Lab", "The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the poverty gaps relative the poverty line", "LAC Equity Lab tabulations of SEDLAC (CEDLAS and the World Bank).", "Poverty"], ["1.0.PSev.Poor4uds", "Poverty Severity ($4 a day)", NaN, "LAC Equity Lab", "The poverty severity index combines information on both poverty and inequality among the poor by averaging the squares of the pov ...

# %% [markdown]
# or globally:

# %%
opt.maxBytes = 2 ** 20
df
# Out:
#                             id  \
# 0           1.0.HCount.1.90usd
# 1            1.0.HCount.2.5usd
# 2         1.0.HCount.Mid10to50
# 3              1.0.HCount.Ofcl
# 4          1.0.HCount.Poor4uds
# ..                         ...
# 495    5.2.11_ETH.BAS.AID.JICA
# 496      5.2.11_KHM.BAS.AID.WB
# 497   5.2.11_LAO.BAS.AID.INGOS
# 498      5.2.11_MWI.BAS.AID.WB
# 499  5.2.11_TLS.TOT.AID.UNICEF
#
#                                                   name  unit  \
# 0                      Poverty Headcount ($1.90 a day)   NaN
# 1                      Poverty Headcount ($2.50 a day)   NaN
# 2                Middle Class ($10-50 a day) Headcount   NaN
# 3              Official Moderate Poverty Rate-National   NaN
# 4                         Poverty Headcount ($4 a day)   NaN
# ..                                                 ...   ...
# 495  International aid disbursed to basic education...   NaN
# 496   International aid disbursed to basic educatio...   NaN
# 497   International aid disbursed to basic educatio...   NaN
# 498  International aid disbursed to basic education...   NaN
# 499   International aid disbursed to total educatio...   NaN
#
#                                source  \
# 0                      LAC Equity Lab
# 1                      LAC Equity Lab
# 2                      LAC Equity Lab
# 3                      LAC Equity Lab
# 4                      LAC Equity Lab
# ..                                ...
# 495  Global Partnership for Education
# 496  Global Partnership for Education
# 497  Global Partnership for Education
# 498  Global Partnership for Education
# 499  Global Partnership for Education
#
#                                             sourceNote  \
# 0    The poverty headcount index measures the propo...
# 1    The poverty headcount index measures the propo...
# 2    The poverty headcount index measures the propo...
# 3    The poverty headcount index measures the propo...
# 4    The poverty headcount index measures the propo...
# ..                                                 ...
# 495  International concessional aid disbursed by th...
# 496  International concessional aid disbursed by th...
# 497  International concessional aid disbursed by th...
# 498  International concessional aid disbursed by th...
# 499  International concessional aid disbursed by th...
#
#                                     sourceOrganization   topics
# 0    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 1    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 2    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# 3    LAC Equity Lab tabulations of data from Nation...  Poverty
# 4    LAC Equity Lab tabulations of SEDLAC (CEDLAS a...  Poverty
# ..                                                 ...      ...
# 495  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 496  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 497  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 498  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
# 499  The 2011 Monitoring Exercise on Aid Effectiven...      NaN
#
# [500 rows x 7 columns]
