# %% [markdown]
# # Interactive Tables
#
# **Pandas DataFrames as Interactive DataTables**
#
# [![Pypi](https://img.shields.io/pypi/v/itables.svg)](https://pypi.python.org/pypi/itables)
# ![CI](https://github.com/mwouts/itables/workflows/CI/badge.svg)
# [![codecov.io](https://codecov.io/github/mwouts/itables/coverage.svg?branch=main)](https://codecov.io/github/mwouts/itables?branch=main)
# [![Language grade: Python](https://img.shields.io/lgtm/grade/python/g/mwouts/itables.svg)](https://lgtm.com/projects/g/mwouts/itables/context:python)
# [![Code style: black](https://img.shields.io/badge/code%20style-black-000000.svg)](https://github.com/psf/black)
# <a class="github-button" href="https://github.com/mwouts/itables" data-icon="octicon-star" data-show-count="true" aria-label="Star mwouts/itables on GitHub">Star</a>
# <script async defer src="https://buttons.github.io/buttons.js"></script>
#
# ## Quick start
#
# Install the `itables` package with
#
# ```shell
# pip install itables
# ```
#
# Activate the interactive mode for all series and dataframes with

# %%
from itables import init_notebook_mode

init_notebook_mode(all_interactive=True)

# %% [markdown]
# After this, any Pandas object (DataFrame or Series) is displayed as an interactive [datatables.net](https://datatables.net/) table, which lets you explore, filter or sort your data.

# %%
from itables.sample_dfs import get_countries

df = get_countries()
df
# Out:
#       id iso2Code                                               name  \
# 0    ABW       AW                                              Aruba
# 1    AFE       ZH                        Africa Eastern and Southern
# 2    AFG       AF                                        Afghanistan
# 3    AFR       A9                                             Africa
# 4    AFW       ZI                         Africa Western and Central
# ..   ...      ...                                                ...
# 294  XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# 295  YEM       YE                                        Yemen, Rep.
# 296  ZAF       ZA                                       South Africa
# 297  ZMB       ZM                                             Zambia
# 298  ZWE       ZW                                           Zimbabwe
#
#                          region  \
# 0    Latin America & Caribbean
# 1                    Aggregates
# 2                    South Asia
# 3                    Aggregates
# 4                    Aggregates
# ..                          ...
# 294                  Aggregates
# 295  Middle East & North Africa
# 296         Sub-Saharan Africa
# 297         Sub-Saharan Africa
# 298         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# 0                                                  NaN          High income
# 1                                                  NaN           Aggregates
# 2                                           South Asia           Low income
# 3                                                  NaN           Aggregates
# 4                                                  NaN           Aggregates
# ..                                                 ...                  ...
# 294                                                NaN           Aggregates
# 295  Middle East & North Africa (excluding high inc...           Low income
# 296         Sub-Saharan Africa (excluding high income)  Upper middle income
# 297         Sub-Saharan Africa (excluding high income)  Lower middle income
# 298         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# 0    Not classified  Oranjestad   -70.0167   12.5167
# 1        Aggregates         NaN        NaN       NaN
# 2               IDA       Kabul    69.1761   34.5228
# 3        Aggregates         NaN        NaN       NaN
# 4        Aggregates         NaN        NaN       NaN
# ..              ...         ...        ...       ...
# 294      Aggregates         NaN        NaN       NaN
# 295             IDA      Sana'a    44.2075   15.3520
# 296            IBRD    Pretoria    28.1871  -25.7460
# 297             IDA      Lusaka    28.2937  -15.3982
# 298           Blend      Harare    31.0672  -17.8312
#
# [299 rows x 10 columns]

# %% [markdown]
# If you prefer to render just one series or dataframe as an interactive table, use `show`:

# %%
from itables import show
from itables.sample_dfs import get_population

x = get_population()
show(x)
# Out:
# <table id="01fca719-ed44-49c7-9248-a449ef22c818" class="display"style="max-width:100%"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SP.POP.TOTL</th>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.11.3/css/jquery.dataTables.min.css">
# <style> table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <style> table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# } </style>
# <script type="module">
#     // Define the table data
#     const data = [["Africa Eastern and Southern", 677243300.0], ["Africa Western and Central", 458803500.0], ["Arab World", 436080700.0], ["Caribbean small states", 7442291.0], ["Central Europe and the Baltics", 102253100.0], ["Early-demographic dividend", 3332105000.0], ["East Asia & Pacific", 2360855000.0], ["East Asia & Pacific (excluding high income)", 2113821000.0], ["East Asia & Pacific (IDA & IBRD countries)", 2088016000.0], ["Euro area", 342949800.0], ["Europe & Central Asia", 923452200.0], ["Europe & Central Asia (excluding high income)", 420211700.0], ["Europe & Central Asia (IDA & IBRD countries)", 462209700.0], ["European Union", 447801400.0], ["Fragile and conflict affected situations", 929989600.0], ["Heavily indebted poor countries (HIPC)", 823480000.0], ["High income", 1214930000.0], ["IBRD only", 4862388000.0], ["IDA & IBRD total", 6570992000.0], ["IDA blend", 574159100.0], ["IDA only", 1134445000.0], ["IDA total", 1708604000.0], ["Late-demographic dividend", 2316679000.0], ["Latin America & Caribbean", 652276300.0], ["Latin America & Caribbean (excluding high income)", 595243000.0], ["Latin America & the Caribbean (IDA & IBRD countries)", 636492800.0], ["Least developed countries: UN classification", 1057438000.0], ["Low & middle income", 6518254000.0], ["Low income", 665149000.0], ["Lower middle income", 3330653000.0], ["Middle East & North Africa", 464554100.0], ["Middle East & North Africa (excluding high income)", 396147800.0], ["Middle East & North Africa (IDA & IBRD countries)", 391344600.0], ["Middle income", 5853105000.0], ["North America", 367553300.0], ["Not classified", NaN], ["OECD members", 1370859000.0], ["Other small states", 31941370.0], ["Pacific island small states", 2528958.0], ["Post-demographic dividend", 1115104000.0], ["Pre-demographic dividend", 970795700.0], ["Small states", 41912620.0], ["South Asia", 1856882000.0], ["South Asia (IDA & IBRD)", 1856882000.0], ["Sub-Saharan Africa", 1136047000.0], ["Sub-Saharan Africa (excluding high income)", 1135948000.0], ["Sub-Saharan Africa (IDA & IBRD countries)", 1136047000.0], ["Upper middle income", 2522452000.0], ["World", 7761620000.0], ["Afghanistan", 38928340.0], ["Albania", 2837743.0], ["Algeria", 43851040.0], ["American Samoa", 55197.0], ["Andorra", 77265.0], ["Angola", 32866270.0], ["Antigua and Barbuda", 97928.0], ["Argentina", 45376760.0], ["Armenia", 2963234.0], ["Aruba", 106766.0], ["Australia", 25687040.0], ["Austria", 8917205.0], ["Azerbaijan", 10093120.0], ["Bahamas, The", 393248.0], ["Bahrain", 1701583.0], ["Bangladesh", 164689400.0], ["Barbados", 287371.0], ["Belarus", 9379952.0], ["Belgium", 11556000.0], ["Belize", 397621.0], ["Benin", 12123200.0], ["Bermuda", 63903.0], ["Bhutan", 771612.0], ["Bolivia", 11673030.0], ["Bosnia and Herzegovina", 3280815.0], ["Botswana", 2351625.0], ["Brazil", 212559400.0], ["British Virgin Islands", 30237.0], ["Brunei Darussalam", 437483.0], ["Bulgaria", 6934015.0], ["Burkina Faso", 20903280.0], ["Burundi", 11890780.0], ["Cabo Verde", 555988.0], ["Cambodia", 16718970.0], ["Cameroon", 26545860.0], ["Canada", 38005240.0], ["Cayman Islands", 65720.0], ["Central African Republic", 4829764.0], ["Chad", 16425860.0], ["Channel Islands", 173859.0], ["Chile", 19116210.0], ["China", 1410929000.0], ["Colombia", 50882880.0], ["Comoros", 869595.0], ["Congo, Dem. Rep.", 89561400.0], ["Congo, Rep.", 5518092.0], ["Costa Rica", 5094114.0], ["Cote d'Ivoire", 26378280.0], ["Croatia", 4047200.0], ["Cuba", 11326620.0], ["Curacao", 155014.0], ["Cyprus", 1207361.0], ["Czech Republic", 10698900.0], ["Denmark", 5831404.0], ["Djibouti", 988002.0], ["Dominica", 71991.0], ["Dominican Republic", 10847900.0], ["Ecuador", 17643060.0], ["Egypt, Arab Rep.", 102334400.0], ["El Salvador", 6486201.0], ["Equatorial Guinea", 1402985.0], ["Eritrea", NaN], ["Estonia", 1331057.0], ["Eswatini", 1160164.0], ["Ethiopia", 114963600.0], ["Faroe Islands", 48865.0], ["Fiji", 896444.0], ["Finland", 5530719.0], ["France", 67391580.0], ["French P ...

# %% [markdown]
# (NB: In Jupyter Notebook, Jupyter NBconvert and Jupyter Book, you need to call `init_notebook_mode()` before using `show`).
#
# ## Advanced parameters
#
# The `show` method let you pass parameters to [datatables.net](https://datatables.net/)'s `DataTable()`'s constructor - see the [advanced parameters examples](advanced_parameters.md).
#
# ## Try ITables on Binder
#
# You can run our examples notebooks directly on [![Lab](https://img.shields.io/badge/Binder-JupyterLab-blue.svg)](https://mybinder.org/v2/gh/mwouts/itables/main?urlpath=lab/tree/docs/quick_start.md), without having to install anything on your side.
